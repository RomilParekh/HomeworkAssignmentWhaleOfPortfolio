# %%
import pandas as pd
import requests
import json
from pprint import pprint

# %%
ticker = "GOOGL"
url = f'https://www.quandl.com/api/v3/datasets/WIKI/{ticker}.json'

# %%
print(url)
# Out:
# https://www.quandl.com/api/v3/datasets/WIKI/GOOGL.json

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
type(resp)
# Out:
# requests.models.Response

# %%
ticker_data = resp.json()

# %%
type(ticker_data)
# Out:
# dict

# %%
#pprint(ticker_data)

# %%
#json.dumps(ticker_data, indent = 3)

# %%
tickerCol = ticker_data['dataset']["column_names"]

# %%
data = ticker_data['dataset']["data"]

# %%
ohlc_data_df = pd.DataFrame(data,columns = tickerCol)

# %%
ohlc_data_df
# Out:
#             Date     Open     High      Low     Close      Volume  \
# 0     2018-03-27  1063.90  1064.54   997.62  1006.940   2940957.0
# 1     2018-03-26  1050.60  1059.27  1010.58  1054.090   3272409.0
# 2     2018-03-23  1051.37  1066.78  1024.87  1026.550   2413517.0
# 3     2018-03-22  1080.01  1083.92  1049.64  1053.150   3418154.0
# 4     2018-03-21  1092.57  1108.70  1087.21  1094.000   1990515.0
# ...          ...      ...      ...      ...       ...         ...
# 3419  2004-08-25   104.76   108.00   103.88   106.000   9188600.0
# 3420  2004-08-24   111.24   111.60   103.57   104.870  15247300.0
# 3421  2004-08-23   110.76   113.48   109.05   109.400  18256100.0
# 3422  2004-08-20   101.01   109.08   100.50   108.310  22834300.0
# 3423  2004-08-19   100.01   104.06    95.96   100.335  44659000.0
#
#       Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# 0             0.0          1.0  1063.900000  1064.540000   997.620000
# ...

# %%
ohlc_data_df.set_index('Date')
# Out:
#                Open     High      Low     Close      Volume  Ex-Dividend  \
# Date
# 2018-03-27  1063.90  1064.54   997.62  1006.940   2940957.0          0.0
# 2018-03-26  1050.60  1059.27  1010.58  1054.090   3272409.0          0.0
# 2018-03-23  1051.37  1066.78  1024.87  1026.550   2413517.0          0.0
# 2018-03-22  1080.01  1083.92  1049.64  1053.150   3418154.0          0.0
# 2018-03-21  1092.57  1108.70  1087.21  1094.000   1990515.0          0.0
# ...             ...      ...      ...       ...         ...          ...
# 2004-08-25   104.76   108.00   103.88   106.000   9188600.0          0.0
# 2004-08-24   111.24   111.60   103.57   104.870  15247300.0          0.0
# 2004-08-23   110.76   113.48   109.05   109.400  18256100.0          0.0
# 2004-08-20   101.01   109.08   100.50   108.310  22834300.0          0.0
# 2004-08-19   100.01   104.06    95.96   100.335  44659000.0          0.0
#
#             Split Ratio    Adj. Open    Adj. High     Adj. Low   Adj. Close  \
# Date
# ...
